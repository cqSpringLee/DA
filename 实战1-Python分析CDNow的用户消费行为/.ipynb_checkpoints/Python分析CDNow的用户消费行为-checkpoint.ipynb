# %% [markdown]
# # Python分析CDNow的用户消费行为

# %% [markdown]
# ****
# ### 这是一份用户消费的分析报告
# ### 数据来源于国外
# ****

# %%
import pandas as pd
import numpy as np

# %%
columns=['user_id','order_dt','order_products','order_amount']
df=pd.read_table('CDNOW_master.txt',names=columns,sep='\s+') #s+表示空格分割

# %% [markdown]
# #### 说明
#     * user_id:用户id
#     * order_dt:购买日期
#     * order_products:购买产品数
#     * roder_amount:购买金额

# %%
# 先看5个数据观察下，日趋识别是证书形式
df.head()
# Out:
#    user_id  order_dt  order_products  order_amount
# 0        1  19970101               1         11.77
# 1        2  19970112               1         12.00
# 2        2  19970112               5         77.00
# 3        3  19970102               2         20.76
# 4        3  19970330               2         20.76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69659 entries, 0 to 69658
# Data columns (total 4 columns):
# user_id           69659 non-null int64
# order_dt          69659 non-null int64
# order_products    69659 non-null int64
# order_amount      69659 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 2.1 MB

# %%
df.describe()
# Out:
#             user_id      order_dt  order_products  order_amount
# count  69659.000000  6.965900e+04    69659.000000  69659.000000
# mean   11470.854592  1.997228e+07        2.410040     35.893648
# std     6819.904848  3.837735e+03        2.333924     36.281942
# min        1.000000  1.997010e+07        1.000000      0.000000
# 25%     5506.000000  1.997022e+07        1.000000     14.490000
# 50%    11410.000000  1.997042e+07        2.000000     25.980000
# 75%    17273.000000  1.997111e+07        3.000000     43.700000
# max    23570.000000  1.998063e+07       99.000000   1286.010000

# %% [markdown]
# * 大部分购买数量在2.4个左右，有极值干扰
#
# * 消费金额在36左右

# %% [markdown]
# ### 日期转化

# %%
df['order_dt']=pd.to_datetime(df.order_dt,format="%Y%m%d") 
#df['month']=df.order_dt.values #下面操作就是按照月份分组，转为列表
df['month']=df.order_dt.values.astype('datetime64[M]') #新增数据，时间维度转换按照月份

# %%
df.head(3)
# Out:
#    user_id   order_dt  order_products  order_amount      month
# 0        1 1997-01-01               1         11.77 1997-01-01
# 1        2 1997-01-12               1         12.00 1997-01-01
# 2        2 1997-01-12               5         77.00 1997-01-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69659 entries, 0 to 69658
# Data columns (total 5 columns):
# user_id           69659 non-null int64
# order_dt          69659 non-null datetime64[ns]
# order_products    69659 non-null int64
# order_amount      69659 non-null float64
# month             69659 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2)
# memory usage: 2.7 MB

# %% [markdown]
# ## 1、进行用户消费趋势的分析（按月）
#         * 每月的消费总金额
#         * 每月的消费次数
#         * 每月的产品购买量
#         * 每月的消费人数

# %%
grouped_month = df.groupby('month') #按照月份分组
order_month_amount = grouped_month.order_amount.sum() #计算每月总金额
order_month_amount.head()
# Out:
# month
# 1997-01-01    299060.17
# 1997-02-01    379590.03
# 1997-03-01    393155.27
# 1997-04-01    142824.49
# 1997-05-01    107933.30
# Name: order_amount, dtype: float64

# %%
# 加载数据可视化
import matplotlib.pyplot as plt
#有才会显示图像
# %matplotlib inline  
plt.style.use('ggplot') #绘图风格
#解决中文显示问题
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
#设置图标标题
plt.title("每月消费总金额",fontsize = 20)
#设置坐标轴标签
plt.xlabel("月份",fontsize = 14)
plt.ylabel("月总金额",fontsize = 14)
order_month_amount.plot()

# %% [markdown]
# ### 由上图可知，消费金额前三个月达到高峰，后面消费较为稳定

# %%
plt.plot(order_month_amount.cumsum()) #消费总趋势

# %%
# 月里面用户数量统计
grouped_month.user_id.count().plot()

# %% [markdown]
# 前三月每月订单量在一万左右，后面每月维持在2500左右

# %%
products=grouped_month.order_products.sum().plot() #月总产品数

# %% [markdown]
# ### 前三个月消费订单在15000左右，后面稳定在3500

# %% [markdown]
# ### 统计消费人数
# 对月消费的用户遍历去重。默认保留第一个

# %%
df.groupby('month').user_id.apply(lambda x:len(x.drop_duplicates())).plot() #聚合然后去重

# %%
### 或者使用下面方法

# %%
df.groupby(['month','user_id']).count().reset_index() #分组相当于已经去重了
# Out:
#            month  user_id  order_dt  order_products  order_amount
# 0     1997-01-01        1         1               1             1
# 1     1997-01-01        2         2               2             2
# 2     1997-01-01        3         1               1             1
# 3     1997-01-01        4         2               2             2
# 4     1997-01-01        5         2               2             2
# 5     1997-01-01        6         1               1             1
# 6     1997-01-01        7         1               1             1
# 7     1997-01-01        8         1               1             1
# 8     1997-01-01        9         1               1             1
# 9     1997-01-01       10         1               1             1
# 10    1997-01-01       11         2               2             2
# 11    1997-01-01       12         1               1             1
# 12    1997-01-01       13         1               1             1
# 13    1997-01-01       14         1               1             1
# 14    1997-01-01       15         1               1             1
# 15    1997-01-01       16         1               1             1
# 16    1997-01-01       17         1               1             1
# 17    1997-01-01       18         1               1             1
# 18    1997-01-01       19         1               1             1
# 19    1997-01-01       20         2               2             2
# 20    1997-01-01       21         2               2             2
# 21    1997-01-01       22         1               1             1
# 22    1997-01-01       23         1               1             1
# 23    1997-01-01       24         1               1             1
# 24    1997-01-01       25         1               1             1
# 25    1997-01-01       26         2               2             2
# 26    1997-01-01       27         2               2             2
# 27    1997-01-01       28         2               2             2
# 28    1997-01-01       29         1               1             1
# 29    1997-01-01       30         1               1             1
# ...          ...      ...       ...             ...           ...
# 55349 1998-06-01    23075         1               1             1
# 55350 1998-06-01    23105         3               3             3
# 55351 1998-06-01    23111         1               1             1
# 55352 1998-06-01    23121         1               1             1
# 55353 1998-06-01    23124         2               2             2
# 55354 1998-06-01    23125         1               1             1
# 55355 1998-06-01    23138         1               1             1
# 55356 1998-06-01    23147         1               1             1
# 55357 1998-06-01    23149         3               3             3
# 55358 1998-06-01    23162         4               4             4
# 55359 1998-06-01    23198         1               1             1
# 55360 1998-06-01    23204         1               1             1
# 55361 1998-06-01    23216         1               1             1
# 55362 1998-06-01    23231         1               1             1
# 55363 1998-06-01    23245         2               2             2
# 55364 1998-06-01    23256         2               2             2
# 55365 1998-06-01    23271         1               1             1
# 55366 1998-06-01    23275         1               1             1
# 55367 1998-06-01    23338         1               1             1
# 55368 1998-06-01    23369         1               1             1
# 55369 1998-06-01    23380         3               3             3
# 55370 1998-06-01    23394         1               1             1
# 55371 1998-06-01    23402         1               1             1
# 55372 1998-06-01    23425         1               1             1
# 55373 1998-06-01    23443         1               1             1
# 55374 1998-06-01    23444         1               1             1
# 55375 1998-06-01    23489         1               1             1
# 55376 1998-06-01    23513         1               1             1
# 55377 1998-06-01    23555         1               1             1
# 55378 1998-06-01    23556         1               1             1
#
# [55379 rows x 5 columns]

# %%
df.head(3)
# Out:
#    user_id   order_dt  order_products  order_amount      month
# 0        1 1997-01-01               1         11.77 1997-01-01
# 1        2 1997-01-12               1         12.00 1997-01-01
# 2        2 1997-01-12               5         77.00 1997-01-01

# %% [markdown]
# ### 数据透视表
# pd.pivot_table()
# 主要有3个参数，index, columns,value, 以及aggfunc
#
# index相当于行标签
# columns相当于列标签
# value相当于用来计算值，配合aggfunc来计算count/mean/average
# 注意value不能使用index 和columns已经使用过的值，这点和excel不同。

# %%
df.pivot_table(index = 'month',
               values = ['order_products','order_amount','user_id'],
               aggfunc={'order_products':'sum',
                          'order_amount':'sum',
                          'user_id':'count'}).head() #每月订单数
# Out:
#             order_amount  order_products  user_id
# month
# 1997-01-01     299060.17           19416     8928
# 1997-02-01     379590.03           24921    11272
# 1997-03-01     393155.27           26159    11598
# 1997-04-01     142824.49            9729     3781
# 1997-05-01     107933.30            7275     2895

# %% [markdown]
# ## 2、用户个体消费分析
#     - 用户消费金额，消费次数描述统计
#     - 用户消费金额和消费的散点图
#     - 用户消费次数的分布
#     - 用户累计消费金额占比

# %%
grouped_user = df.groupby('user_id')  #用户分组

# %%
grouped_user.sum().describe()
# Out:
#        order_products  order_amount
# count    23570.000000  23570.000000
# mean         7.122656    106.080426
# std         16.983531    240.925195
# min          1.000000      0.000000
# 25%          1.000000     19.970000
# 50%          3.000000     43.395000
# 75%          7.000000    106.475000
# max       1033.000000  13990.930000

# %% [markdown]
#  * 用户购买了7张CD，但是中位数是3，说明小部分用户购买了大量CD
#  * 用户平均消费100元，中位数43，判断同上
#  * max的值的很恐怖 符合二八定律

# %%
# plot.scatter 散点图
grouped_user.sum().plot.scatter(x='order_amount',y='order_products')

# %% [markdown]
# ### 增加查询条件，过滤异常值。
# ### query类似SQL的where

# %%
grouped_user.sum().query('order_amount < 4000').plot.scatter(x='order_amount',y='order_products')

# %%
# 分为20层
grouped_user.sum().order_amount.plot.hist(bins = 20)

# %% [markdown]
# 直方图可以看出集中趋势

# %%
# 分为50层
grouped_user.sum().query('order_products < 100').order_amount.plot.hist(bins = 50)

# %% [markdown]
#  切比雪夫定理过滤异常值，计算95%的数据分布情况

# %%
grouped_user.sum().sort_values('order_amount').cumsum() #累加求和
# Out:
#          order_products  order_amount
# user_id
# 10175               1.0          0.00
# 4559                2.0          0.00
# 1948                3.0          0.00
# 925                 4.0          0.00
# 10798               5.0          0.00
# 19314               6.0          0.00
# 21690               7.0          0.00
# 10664               8.0          0.00
# 4384                9.0          0.00
# 6395               10.0          0.00
# 19384              11.0          0.00
# 23157              12.0          0.00
# 455                13.0          0.00
# 2556               14.0          0.00
# 1987               15.0          0.00
# 9853               16.0          0.00
# 9835               17.0          0.00
# 6920               18.0          0.00
# 908                19.0          0.00
# 9710               20.0          0.00
# 13434              21.0          0.00
# 19189              22.0          0.00
# 12366              23.0          0.00
# 16132              24.0          0.00
# 5567               25.0          0.00
# 5301               26.0          0.00
# 11955              27.0          0.00
# 11940              28.0          0.00
# 1753               29.0          0.00
# 18861              30.0          0.00
# ...                 ...           ...
# 22492          159285.0    2375686.36
# 3901           159459.0    2378097.89
# 16175          159641.0    2380515.43
# 313            159815.0    2382947.72
# 710            159945.0    2385450.02
# 8250           160106.0    2388032.76
# 12098          160228.0    2390627.09
# 17337          160392.0    2393226.71
# 586            160579.0    2396076.35
# 2908           160767.0    2398991.22
# 21950          160971.0    2401974.02
# 20917          161193.0    2405051.47
# 21739          161376.0    2408371.30
# 1077           161535.0    2411695.79
# 14894          161668.0    2415059.72
# 12367          161931.0    2418857.96
# 13167          162223.0    2422756.66
# 22061          162490.0    2426705.56
# 2664           162741.0    2430805.83
# 16517          163040.0    2434990.93
# 15162          163222.0    2439225.38
# 3049           163523.0    2443488.23
# 499            163851.0    2447866.78
# 22279          164181.0    2452357.42
# 6569           164503.0    2457325.42
# 7931           165017.0    2463822.60
# 19339          165395.0    2470375.30
# 7983           165931.0    2477348.37
# 14048          166964.0    2486324.70
# 7592           167881.0    2500315.63
#
# [23570 rows x 2 columns]

# %%
user_cumsum = grouped_user.sum().sort_values('order_amount').apply(lambda x:x.cumsum() / x.sum())  #累加值除以总数
# 设置坐标轴的lable
plt.title('累计消费金额')
plt.xlabel('人数')
plt.ylabel('消费额度')
user_cumsum.reset_index().order_amount.plot()  #reset_index()去掉索引，方便作图

# %% [markdown]
# ####  15%消费额是50%用户完成的，50%消费额是顶尖5000人消费完成的！

# %% [markdown]
# ## 3.用户消费行为
#     * 用户第一次消费
#     * 用户最后次消费
#     * 新老客消费比
#         * 多少用户仅仅消费了一次
#         * 每月新客占比
#     * 用户分层
#         * RFM
#         * 新、老、活跃、回流、流失
#     * 用户购买周期（按订单）
#         * 用户消费周期描述
#         * 用户消费周期分布
#     * 用户生命周期
#          * 用户生命周期描述
#          * 用户生命周期分布

# %%
grouped_user.min()
# Out:
#           order_dt  order_products  order_amount      month
# user_id
# 1       1997-01-01               1         11.77 1997-01-01
# 2       1997-01-12               1         12.00 1997-01-01
# 3       1997-01-02               1         16.99 1997-01-01
# 4       1997-01-01               1         14.96 1997-01-01
# 5       1997-01-01               1         13.97 1997-01-01
# 6       1997-01-01               1         20.99 1997-01-01
# 7       1997-01-01               2         28.74 1997-01-01
# 8       1997-01-01               1          2.99 1997-01-01
# 9       1997-01-01               2         23.54 1997-01-01
# %% [markdown]
#     用户最后次购买的分布比第一次分布广
#     大部分最后次购买集中在前三个月，说明很多用户购买一次后就不购买了
#     随着时间递增，最后一次购买数也在增长，消费呈现流失上升的情况

# %%
#新老客消费比
user_life = grouped_user.order_dt.agg(['min','max']) #第一次消费和最后次消费
user_life.head()
# Out:
#                min        max
# user_id
# 1       1997-01-01 1997-01-01
# 2       1997-01-12 1997-01-12
# 3       1997-01-02 1998-05-28
# 4       1997-01-01 1997-12-12
# 5       1997-01-01 1998-01-03

# %%
(user_life['min'] == user_life['max']).value_counts() #第一次消费=最后次消费，即是消费了一次
# Out:
# True     12054
# False    11516
# dtype: int64

# %% [markdown]
# ### 有一半用户就只消费了一次

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of        user_id   order_dt  order_products  order_amount      month
# 0            1 1997-01-01               1         11.77 1997-01-01
# 1            2 1997-01-12               1         12.00 1997-01-01
# 2            2 1997-01-12               5         77.00 1997-01-01
# 3            3 1997-01-02               2         20.76 1997-01-01
# 4            3 1997-03-30               2         20.76 1997-03-01
# 5            3 1997-04-02               2         19.54 1997-04-01
# 6            3 1997-11-15               5         57.45 1997-11-01
# 7            3 1997-11-25               4         20.96 1997-11-01
# 8            3 1998-05-28               1         16.99 1998-05-01
# 9            4 1997-01-01               2         29.33 1997-01-01
# 10           4 1997-01-18               2         29.73 1997-01-01
# 11           4 1997-08-02               1         14.96 1997-08-01
# 12           4 1997-12-12               2         26.48 1997-12-01
# 13           5 1997-01-01               2         29.33 1997-01-01
# 14           5 1997-01-14               1         13.97 1997-01-01
# 15           5 1997-02-04               3         38.90 1997-02-01
# 16           5 1997-04-11               3         45.55 1997-04-01
# 17           5 1997-05-31               3         38.71 1997-05-01
# 18           5 1997-06-16               2         26.14 1997-06-01
# 19           5 1997-07-22               2         28.14 1997-07-01
# 20           5 1997-09-15               3         40.47 1997-09-01
# 21           5 1997-12-08               4         46.46 1997-12-01
# 22           5 1997-12-12               3         40.47 1997-12-01
# 23           5 1998-01-03               3         37.47 1998-01-01
# 24           6 1997-01-01               1         20.99 1997-01-01
# 25           7 1997-01-01               2         28.74 1997-01-01
# 26           7 1997-10-11               7         97.43 1997-10-01
# 27           7 1998-03-22               9        138.50 1998-03-01
# 28           8 1997-01-01               1          9.77 1997-01-01
# 29           8 1997-02-13               1         13.97 1997-02-01
# ...        ...        ...             ...           ...        ...
# 69629    23556 1997-09-27               3         31.47 1997-09-01
# 69630    23556 1998-01-03               2         28.98 1998-01-01
# 69631    23556 1998-06-07               2         28.98 1998-06-01
# 69632    23557 1997-03-25               1         14.37 1997-03-01
# 69633    23558 1997-03-25               2         28.13 1997-03-01
# 69634    23558 1997-05-18               3         45.51 1997-05-01
# 69635    23558 1997-06-24               2         23.74 1997-06-01
# 69636    23558 1998-02-25               4         48.22 1998-02-01
# 69637    23559 1997-03-25               2         23.54 1997-03-01
# 23553           98.58 1997-03-28               8
# 23554           36.37 1998-02-01               3
# 23555          189.18 1998-06-10              14
# 23556          203.00 1998-06-07              15
# 23557           14.37 1997-03-25               1
# 23558          145.60 1998-02-25              11
# 23559          111.65 1997-06-27               8
# 23560           18.36 1997-03-25               1
# 23561           83.46 1998-05-29               6
# 23562           29.33 1997-03-25               2
# 23563           58.75 1997-10-04               3
# 23564           70.01 1997-11-30               5
# 23565           11.77 1997-03-25               1
# 23566           36.00 1997-03-25               2
# 23567           20.97 1997-03-25               1
# 23568          121.70 1997-04-22               6
# 23569           25.74 1997-03-25               2
# 23570           94.08 1997-03-26               5
#
# [23570 rows x 3 columns]

# %%
-(rfm.order_dt - rfm.order_dt.max()) #日期相减是天数
# Out:
# user_id
# 1       545 days
# 2       534 days
# 3        33 days
# 4       200 days
# 5       178 days
# 6       545 days
# 7       100 days
# 8        93 days
# 9        22 days
# 10      525 days
# 11      130 days
# 12      545 days
# 13      545 days
# 14      545 days
# 15      545 days
# 16      293 days
# 17      545 days
# 18      542 days
# 19      385 days
# 20      528 days
# 21      533 days
# 22      545 days
# 23      545 days
# 24      161 days
# 25       22 days
# 26      520 days
# 27      534 days
# 28      479 days
# 29       65 days
# 30      501 days
#           ...
# 23541   454 days
# 23542   462 days
# 23543   462 days
# 23544   157 days
# 23545   462 days
# 23546   462 days
# 23547   449 days
# 23548   462 days
# 23549   462 days
# 23550   462 days
# 23551   292 days
# 23552   453 days
# 23553   459 days
# 23554   149 days
# 23555    20 days
# 23556    23 days
# 23557   462 days
# 23558   125 days
# 23559   368 days
# 23560   462 days
# 23561    32 days
# 23562   462 days
# 23563   269 days
# 23564   212 days
# 23565   462 days
# 23566   462 days
# 23567   462 days
# 23568   434 days
# 23569   462 days
# 23570   461 days
# Name: order_dt, Length: 23570, dtype: timedelta64[ns]

# %%
rfm['R']=-(rfm.order_dt - rfm.order_dt.max()) / np.timedelta64(1,'D')  #除法天数为了消除单位天
rfm.rename(columns={'order_products':'F','order_amount':'M'},inplace=True)  #构造列
rfm  #构造rfm字段，RFM分析（Recency，Frequency，Monetary）
# Out:
#               M   order_dt   F      R
# user_id
# 1         11.77 1997-01-01   1  545.0
# 2         89.00 1997-01-12   6  534.0
# 3        156.46 1998-05-28  16   33.0
# 4        100.50 1997-12-12   7  200.0
# 5        385.61 1998-01-03  29  178.0
# 6         20.99 1997-01-01   1  545.0
# 7        264.67 1998-03-22  18  100.0
# 8        197.66 1998-03-29  18   93.0
# 9         95.85 1998-06-08   6   22.0
# 10        39.31 1997-01-21   3  525.0
# 11        58.55 1998-02-20   4  130.0
# 12        57.06 1997-01-01   4  545.0
# 13        72.94 1997-01-01   4  545.0
# 14        29.92 1997-01-01   2  545.0
# 15        52.87 1997-01-01   4  545.0
# 16        79.87 1997-09-10   8  293.0
# 17        73.22 1997-01-01   5  545.0
# 18        14.96 1997-01-04   1  542.0
# 23558   -242.221638   3.877344   39.519574
# 23559      0.778362   0.877344    5.569574
# 23560     94.778362  -6.122656  -87.720426
# 23561   -335.221638  -1.122656  -22.620426
# 23562     94.778362  -5.122656  -76.750426
# 23563    -98.221638  -4.122656  -47.330426
# 23564   -155.221638  -2.122656  -36.070426
# 23565     94.778362  -6.122656  -94.310426
# 23566     94.778362  -5.122656  -70.080426
# 23567     94.778362  -6.122656  -85.110426
# 23568     66.778362  -1.122656   15.619574
# 23569     94.778362  -5.122656  -80.340426
# 23570     93.778362  -2.122656  -12.000426
#
# [23570 rows x 3 columns]

# %%
def rfm_func(x):
    level = x.apply(lambda x : '1' if x >= 0 else '0') #字符串
    label = level.R + level.F +level.M
    d = {
        '111':'重要价值客户',
        '011':'重要保持客户',
        '101':'重要发展客户',
        '001':'重要挽留客户',
        '110':'一般价值客户',
        '010':'一般保持客户',
        '100':'一般发展客户',
        '000':'一般挽留客户'
        }
    result = d[label]
    return result

rfm['label'] = rfm[['R','F','M']].apply(lambda x : x-x.mean()).apply(rfm_func,axis = 1)

# %%
rfm
# Out:
#               M   order_dt   F      R   label
# user_id
# 1         11.77 1997-01-01   1  545.0  一般发展客户
# 2         89.00 1997-01-12   6  534.0  一般发展客户
# 3        156.46 1998-05-28  16   33.0  重要保持客户
# 4        100.50 1997-12-12   7  200.0  一般挽留客户
# 5        385.61 1998-01-03  29  178.0  重要保持客户
# 6         20.99 1997-01-01   1  545.0  一般发展客户
# 7        264.67 1998-03-22  18  100.0  重要保持客户
# 8        197.66 1998-03-29  18   93.0  重要保持客户
# 9         95.85 1998-06-08   6   22.0  一般挽留客户
# 10        39.31 1997-01-21   3  525.0  一般发展客户
# 11        58.55 1998-02-20   4  130.0  一般挽留客户
# 12        57.06 1997-01-01   4  545.0  一般发展客户
# 13        72.94 1997-01-01   4  545.0  一般发展客户
# 14        29.92 1997-01-01   2  545.0  一般发展客户
# 15        52.87 1997-01-01   4  545.0  一般发展客户
# 16        79.87 1997-09-10   8  293.0  一般保持客户
# 17        73.22 1997-01-01   5  545.0  一般发展客户
# 18        14.96 1997-01-04   1  542.0  一般发展客户
# 19       175.12 1997-06-10  11  385.0  重要价值客户
# 20       653.01 1997-01-18  46  528.0  重要价值客户
# 21        75.11 1997-01-13   4  533.0  一般发展客户
# 22        14.37 1997-01-01   1  545.0  一般发展客户
# 23        24.74 1997-01-01   2  545.0  一般发展客户
# 24        57.77 1998-01-20   4  161.0  一般挽留客户
# 25       137.53 1998-06-08  12   22.0  重要保持客户
# 26       102.69 1997-01-26   6  520.0  一般发展客户
# 27       135.87 1997-01-12  10  534.0  重要价值客户
# 28        90.99 1997-03-08   7  479.0  一般发展客户
# 29       435.81 1998-04-26  28   65.0  重要保持客户
# 30        28.34 1997-02-14   2  501.0  一般发展客户
# ...         ...        ...  ..    ...     ...
# 23541     57.34 1997-04-02   2  454.0  一般发展客户
# 23542     77.43 1997-03-25   5  462.0  一般发展客户
# 23543     50.76 1997-03-25   2  462.0  一般发展客户
# 23544    134.63 1998-01-24  12  157.0  重要保持客户
# 23545     24.99 1997-03-25   1  462.0  一般发展客户
# 23546     13.97 1997-03-25   1  462.0  一般发展客户
# 23547     23.54 1997-04-07   2  449.0  一般发展客户
# 23548     23.54 1997-03-25   2  462.0  一般发展客户
# 23549     27.13 1997-03-25   2  462.0  一般发展客户
# 23550     25.28 1997-03-25   2  462.0  一般发展客户
# 23551    264.63 1997-09-11  12  292.0  重要保持客户
# 23552     49.38 1997-04-03   4  453.0  一般发展客户
# 23553     98.58 1997-03-28   8  459.0  一般价值客户
# 23554     36.37 1998-02-01   3  149.0  一般挽留客户
# 23555    189.18 1998-06-10  14   20.0  重要保持客户
# 23556    203.00 1998-06-07  15   23.0  重要保持客户
# 23557     14.37 1997-03-25   1  462.0  一般发展客户
# 23558    145.60 1998-02-25  11  125.0  重要保持客户
# 23559    111.65 1997-06-27   8  368.0  重要价值客户
# 23560     18.36 1997-03-25   1  462.0  一般发展客户
# 23561     83.46 1998-05-29   6   32.0  一般挽留客户
# 23562     29.33 1997-03-25   2  462.0  一般发展客户
# 23563     58.75 1997-10-04   3  269.0  一般挽留客户
# 23564     70.01 1997-11-30   5  212.0  一般挽留客户
# 23565     11.77 1997-03-25   1  462.0  一般发展客户
# 23566     36.00 1997-03-25   2  462.0  一般发展客户
# 23567     20.97 1997-03-25   1  462.0  一般发展客户
# 23568    121.70 1997-04-22   6  434.0  重要发展客户
# 23569     25.74 1997-03-25   2  462.0  一般发展客户
# 23570     94.08 1997-03-26   5  461.0  一般发展客户
#
# [23570 rows x 5 columns]

# %%
rfm.groupby('label').count()
# Out:
#             M  order_dt      F      R
# label
# 一般价值客户     77        77     77     77
# 一般保持客户    206       206    206    206
# 一般发展客户  14074     14074  14074  14074
# 一般挽留客户   3300      3300   3300   3300
# 重要价值客户    787       787    787    787
# 重要保持客户   4554      4554   4554   4554
# 重要发展客户    241       241    241    241
# 重要挽留客户    331       331    331    331

# %%
rfm.groupby('label').sum()
# Out:
#                  M       F          R
# label
# 一般价值客户     7181.28     650    36295.0
# 一般保持客户    19937.45    1712    29448.0
# 一般发展客户   438291.81   29346  6951815.0
# 一般挽留客户   196971.23   13977   591108.0
# 重要价值客户   167080.83   11121   358363.0
# 重要保持客户  1592039.62  107789   517267.0
# 重要发展客户    33028.40    1263   114482.0
# 重要挽留客户    45785.01    2023    56636.0

# %%
rfm.loc[rfm.label == '重要价值客户','color'] = 'y'
rfm.loc[~(rfm.label == '重要价值客户'),'color'] = 'r'
rfm.plot.scatter('F','R',c=rfm.color)

# %% [markdown]
# 从RFM 分层可知，大部分用户为重要保持客户，但是这是由于极值的影响，所有RFM的划分应该以业务为准
#    * 尽量用小部分的用户覆盖大部分的额度
#    * 不要为了数据好看划分等级

# %%
# 可以做出8种图
